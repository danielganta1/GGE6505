# %%
import pandas as pd

# %%
actors_url = "/content/actors.csv"
actors_data = pd.read_csv(actors_url)
display(actors_data)
actors_data.isnull().sum()
# Out:
#                  stage        dow   birth      giv gen      dob   dod  \
# 0         Willie Aames        NaN   Aames  William   M     1960  199x
# 1           Bud Abbott  1939-1956  Abbott  William   M     1895  1974
# 2       Diahnne Abbott  1976-1982     NaN      NaN   F  [1][23]  199x
# 3        George Abbott  1928-1958  Abbott   George   M     1887  199x
# 4          John Abbott  1937-1975  Abbott     John   M     1905  199x
# ...                ...        ...     ...      ...  ..      ...   ...
# 6845      David Zucker        NaN     NaN      NaN   M      [1]  199x
# 6846      Jerry Zucker        NaN     NaN      NaN   M      [1]  199x
# 6847     Daphne Zuniga        NaN     NaN      NaN   F      [1]  199x
# 6848  Frantisek Zvarik        NaN     NaN      NaN   M      [1]  199x
# 6849  Darrell Zwerling        NaN     NaN      NaN   M      [1]  199x
#
#                                  type      orig
# 0                                 RU:       \Am
# ...

# %%
import matplotlib.pyplot as plt

plt.hist(actors_data['gen'], bins=10)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-59-9a1ee93d0d1b> in <module>
#       1 import matplotlib.pyplot as plt
#       2
# ----> 3 plt.hist(actors_data['gen'], bins=10)
#       4 plt.show()
#
# /usr/local/lib/python3.9/dist-packages/matplotlib/pyplot.py in hist(x, bins, range, density, weights, cumulative, bottom, histtype, align, orientation, rwidth, log, color, label, stacked, data, **kwargs)
#    2643         orientation='vertical', rwidth=None, log=False, color=None,
#    2644         label=None, stacked=False, *, data=None, **kwargs):
# -> 2645     return gca().hist(
#    2646         x, bins=bins, range=range, density=density, weights=weights,
#    2647         cumulative=cumulative, bottom=bottom, histtype=histtype,
#
# /usr/local/lib/python3.9/dist-packages/matplotlib/__init__.py in inner(ax, data, *args, **kwargs)
# ...

# %%
actors_data.describe()
# Out:
#         stage   dow  birth   giv   gen   dob   dod  type  orig  pict  ...  \
# count    6849  4839   4781  4776  6702  6481  6749  6844  6740   770  ...
# unique   6796  2047   3363  2005    26   173   114  1912   175   481  ...
# top     stage   dow  birth  John     M   [1]  199x   RU:   \Am  pict  ...
# freq       30    39     30    95  4066  1935  4654  2372  2670    30  ...
#
#        Unnamed: 15 Unnamed: 16 Unnamed: 17 Unnamed: 18      Unnamed: 19  \
# count            8           9           7           8                8
# unique           8           4           6           6                8
# top           Mary           F        1924        199x  R:pert gun moll
# freq             1           4           2           3                1
#
#        Unnamed: 20 Unnamed: 21    Unnamed: 22 Unnamed: 23 Unnamed: 24
# count            7           2              7           3           1
# unique           1           2              7           2           1
# ...

# %%
actors_data.drop(actors_data.iloc[:, 9:25], inplace=True, axis=1)
display(actors_data)
actors_data.isnull().sum()
# Out:
#                  stage        dow   birth      giv gen      dob   dod  \
# 0         Willie Aames        NaN   Aames  William   M     1960  199x
# 1           Bud Abbott  1939-1956  Abbott  William   M     1895  1974
# 2       Diahnne Abbott  1976-1982     NaN      NaN   F  [1][23]  199x
# 3        George Abbott  1928-1958  Abbott   George   M     1887  199x
# 4          John Abbott  1937-1975  Abbott     John   M     1905  199x
# ...                ...        ...     ...      ...  ..      ...   ...
# 6845      David Zucker        NaN     NaN      NaN   M      [1]  199x
# 6846      Jerry Zucker        NaN     NaN      NaN   M      [1]  199x
# 6847     Daphne Zuniga        NaN     NaN      NaN   F      [1]  199x
# 6848  Frantisek Zvarik        NaN     NaN      NaN   M      [1]  199x
# 6849  Darrell Zwerling        NaN     NaN      NaN   M      [1]  199x
#
#                                  type      orig
# 0                                 RU:       \Am
# ...

# %%
import numpy as np
actors_data['gen'] = actors_data['gen'].fillna('NA')
conditions = [
    actors_data['gen'] == 'M',
    actors_data['gen'] == 'F',
    actors_data['gen'] == 'NA'
]

choice = ['M','F','NA']

actors_data['gen'] = np.select(conditions,choice)
actors_data.isnull().sum()
# Out:
# stage       1
# dow      2011
# birth    2069
# giv      2074
# gen         0
# dob       369
# dod       101
# type        6
# orig      110
# dtype: int64

# %%
actors_data
actors_data.to_csv('/content/actors.csv', index=False)

# %%
import matplotlib.pyplot as plt

plt.hist(actors_data['gen'], bins=10)
plt.show()

# %%
actors_data['gen'].unique()
actors_data.gen.value_counts()
# Out:
# M     4066
# F     2552
# NA     232
# Name: gen, dtype: int64

# %%
actors_data['gen'].mask(actors_data['gen']=='0','NA',inplace = True)
actors_data['gen'].unique()
# Out:
# array(['M', 'F', 'NA'], dtype=object)

# %%
plt.hist(actors_data['gen'], bins=10)
plt.show()

# %%
actors_data
actors_data.to_csv('/content/actors.csv', index=False)

# %%
actors_data['dob'].unique()
actors_data['dob'].mask(actors_data['dob'].str.isnumeric() != True,'0',inplace = True)

# %%
display(actors_data)
# Out:
#                  stage        dow   birth      giv gen   dob   dod  \
# 0         Willie Aames        NaN   Aames  William   M  1960  199x
# 1           Bud Abbott  1939-1956  Abbott  William   M  1895  1974
# 2       Diahnne Abbott  1976-1982     NaN      NaN   F     0  199x
# 3        George Abbott  1928-1958  Abbott   George   M  1887  199x
# 4          John Abbott  1937-1975  Abbott     John   M  1905  199x
# ...                ...        ...     ...      ...  ..   ...   ...
# 6845      David Zucker        NaN     NaN      NaN   M     0  199x
# 6846      Jerry Zucker        NaN     NaN      NaN   M     0  199x
# 6847     Daphne Zuniga        NaN     NaN      NaN   F     0  199x
# 6848  Frantisek Zvarik        NaN     NaN      NaN   M     0  199x
# 6849  Darrell Zwerling        NaN     NaN      NaN   M     0  199x
#
#                                  type      orig
# 0                                 RU:       \Am
# 1                          R:straight  comedian
# ...

# %%
actors_data['dob'].unique()
# Out:
# array(['1960', '1895', '0', '1887', '1905', '1923', '1898', '1928',
#        '1940', '1920', '1902', '1872', '1909', '1896', '1945', '1949',
#        '1950', '1915', '1929', '1921', '1931', '1926', '1906', '1938',
#        '1930', '1912', '1955', '1899', '1903', '1952', '1911', '1932',
#        '1910', '1918', '1936', '1892', '1908', '1951', '1907', '1901',
#        '1925', '1914', '1939', '1942', '1916', '1894', '1934', '1954',
#        '1927', '1935', '1883', '1891', '1917', '1993', '1919', '1962',
#        '1889', '1882', '1922', '1947', '1943', '1948', '1913', '1944',
#        '1941', '1868', '1888', '1900', '1890', '1953', '1884', '1946',
#        '1904', '1897', '1961', '1885', '1870', '1869', '1924', '1964',
#        '1965', '1963', '1967', '1865', '1933', '1976', '1879', '1878',
#        '1867', '1958', '1880', '1937', '1974', '1873', '1956', '1844',
#        '1959', '1893', '1863', '1989', '1886', '1874', '1966', '1876',
# ...

# %%
actors_data = actors_data.loc[actors_data["dob"] != '0']
display(actors_data)
# Out:
#                     stage        dow       birth           giv gen   dob  \
# 0            Willie Aames        NaN       Aames       William   M  1960
# 1              Bud Abbott  1939-1956      Abbott       William   M  1895
# 3           George Abbott  1928-1958      Abbott        George   M  1887
# 4             John Abbott  1937-1975      Abbott          John   M  1905
# 5           Philip Abbott  1957-1973      Abbott        Philip   M  1923
# ...                   ...        ...         ...           ...  ..   ...
# 6837       Mai Zetterling  1944-1983  Zetterling           Mai   F  1925
# 6839        Sonja Ziemann  1942-1970     Ziemann         Sonja   F  1926
# 6840  Efrem Zimbalist~Jr.  1949-1978   Zimbalist     Efrem Jr.   M  1918
# 6843          Vera Zorina  1939-1944     Hartwig  Eva Brigitta   F  1917
# 6844         George Zucco  1930-1951       Zucco        George   M  1886
#
#        dod                             type      orig
# ...

# %%
actors_data.dropna()
# Out:
#                     stage        dow       birth           giv gen   dob  \
# 1              Bud Abbott  1939-1956      Abbott       William   M  1895
# 3           George Abbott  1928-1958      Abbott        George   M  1887
# 4             John Abbott  1937-1975      Abbott          John   M  1905
# 5           Philip Abbott  1957-1973      Abbott        Philip   M  1923
# 7             Walter Abel  1935-1974        Abel        Walter   M  1898
# ...                   ...        ...         ...           ...  ..   ...
# 6837       Mai Zetterling  1944-1983  Zetterling           Mai   F  1925
# 6839        Sonja Ziemann  1942-1970     Ziemann         Sonja   F  1926
# 6840  Efrem Zimbalist~Jr.  1949-1978   Zimbalist     Efrem Jr.   M  1918
# 6843          Vera Zorina  1939-1944     Hartwig  Eva Brigitta   F  1917
# 6844         George Zucco  1930-1951       Zucco        George   M  1886
#
#        dod                             type      orig
# ...

# %%
actors_data['dob'] = actors_data['dob'].astype(int)

# %%
actors_data['dod'].mask(actors_data['dod'].str.isnumeric() != True,'0',inplace = True)

# %%
actors_data
# Out:
#                     stage        dow       birth           giv gen   dob  \
# 0            Willie Aames        NaN       Aames       William   M  1960
# 1              Bud Abbott  1939-1956      Abbott       William   M  1895
# 3           George Abbott  1928-1958      Abbott        George   M  1887
# 4             John Abbott  1937-1975      Abbott          John   M  1905
# 5           Philip Abbott  1957-1973      Abbott        Philip   M  1923
# ...                   ...        ...         ...           ...  ..   ...
# 6837       Mai Zetterling  1944-1983  Zetterling           Mai   F  1925
# 6839        Sonja Ziemann  1942-1970     Ziemann         Sonja   F  1926
# 6840  Efrem Zimbalist~Jr.  1949-1978   Zimbalist     Efrem Jr.   M  1918
# 6843          Vera Zorina  1939-1944     Hartwig  Eva Brigitta   F  1917
# 6844         George Zucco  1930-1951       Zucco        George   M  1886
#
#        dod                             type      orig
# ...

# %%
actors_data = actors_data.loc[actors_data["dod"] != '0']
actors_data['dod'] = actors_data['dod'].astype(int)
# Out:
# <ipython-input-188-5c449e3200bb>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   actors_data['dod'] = actors_data['dod'].astype(int)

# %%
actors_data
# Out:
#                stage        dow   birth      giv gen   dob   dod  \
# 1         Bud Abbott  1939-1956  Abbott  William   M  1895  1974
# 7        Walter Abel  1935-1974    Abel   Walter   M  1898  1987
# 16    Rodolfo Acosta  1948-1967  Acosta  Rodolfo   M  1920  1974
# 17       Eddie Acuff  1935-1947   Acuff    Eddie   M  1902  1956
# 18        Jean Adair  1922-1947   Adair     Jean   F  1872  1956
# ...              ...        ...     ...      ...  ..   ...   ...
# 6809       Gig Young  1940-1978    Barr    Byron   M  1913  1978
# 6814    Robert Young  1931-1975   Young   Robert   M  1907  1998
# 6815    Roland Young  1922-1953   Young   Roland   M  1887  1953
# 6824   Blanche Yurka  1936-1957   Yurka  Blanche   F  1887  1974
# 6844    George Zucco  1930-1951   Zucco   George   M  1886  1960
#
#                                type      orig
# 1                        R:straight  comedian
# 7                  R:harrassed hero       \Am
# ...

# %%
import matplotlib.pyplot as plt
import numpy as np

val = actors_data['dob'].count()
val1 = actors_data[(actors_data['dob']>1850) &(actors_data['dob']<=1900)]['dob'].count()
val2 = actors_data[(actors_data['dob']>1900) &(actors_data['dob']<=1950)]['dob'].count()
val3 = actors_data[(actors_data['dob']>1950) &(actors_data['dob']<=2000)]['dob'].count()

v1 = round(((val1/val)*100))
v2 = round(((val2/val)*100))
v3 = round(((val3/val)*100))

strv1 = "Number of actors born between 1850 and 1900 is " + str(v1) + "%"
strv2 = "Number of actors born between 1900 and 1950 is " + str(v2) + "%"
strv3 = "Number of actors born between 1950 and 2000 is " + str(v3) + "%"

y = np.array([v1,v2,v3])
mylabels = [strv1,strv2,strv3]
plt.pie(y,labels = mylabels)
plt.show()

# %%
a1 = actors_data['gen'].count()
a2 = actors_data[(actors_data['gen'] == 'M')]['gen'].count()
a3 = round((a2/a1)*100)
a4 = actors_data[(actors_data['gen'] == 'F')]['gen'].count()
a5 = round((a4/a1)*100)
a6 = actors_data[(actors_data['gen'] == 'NA')]['gen'].count()
a7 = round((a6/a1)*100)
y = np.array([a3,a5,a7])

stra1 = "Male " + str(a3) + "%"
stra2 = "Female " + str(a5) + "%"
stra3 = "NA " + str(a7) + "%"

mylabel = [stra1,stra2,stra3]
plt.pie(y,labels = mylabel)
plt.show()

# %%
actors_data
# Out:
#                stage        dow   birth      giv gen   dob   dod  \
# 1         Bud Abbott  1939-1956  Abbott  William   M  1895  1974
# 7        Walter Abel  1935-1974    Abel   Walter   M  1898  1987
# 16    Rodolfo Acosta  1948-1967  Acosta  Rodolfo   M  1920  1974
# 17       Eddie Acuff  1935-1947   Acuff    Eddie   M  1902  1956
# 18        Jean Adair  1922-1947   Adair     Jean   F  1872  1956
# ...              ...        ...     ...      ...  ..   ...   ...
# 6809       Gig Young  1940-1978    Barr    Byron   M  1913  1978
# 6814    Robert Young  1931-1975   Young   Robert   M  1907  1998
# 6815    Roland Young  1922-1953   Young   Roland   M  1887  1953
# 6824   Blanche Yurka  1936-1957   Yurka  Blanche   F  1887  1974
# 6844    George Zucco  1930-1951   Zucco   George   M  1886  1960
#
#                                type      orig  age
# 1                        R:straight  comedian   79
# 7                  R:harrassed hero       \Am   89
# ...

# %%
Age = actors_data['dod'] - actors_data['dob']

# %%
actors_data
# Out:
#                stage        dow   birth      giv gen     dob     dod  \
# 1         Bud Abbott  1939-1956  Abbott  William   M  1895.0  1974.0
# 7        Walter Abel  1935-1974    Abel   Walter   M  1898.0  1987.0
# 16    Rodolfo Acosta  1948-1967  Acosta  Rodolfo   M  1920.0  1974.0
# 17       Eddie Acuff  1935-1947   Acuff    Eddie   M  1902.0  1956.0
# 18        Jean Adair  1922-1947   Adair     Jean   F  1872.0  1956.0
# ...              ...        ...     ...      ...  ..     ...     ...
# 6809       Gig Young  1940-1978    Barr    Byron   M  1913.0  1978.0
# 6814    Robert Young  1931-1975   Young   Robert   M  1907.0  1998.0
# 6815    Roland Young  1922-1953   Young   Roland   M  1887.0  1953.0
# 6824   Blanche Yurka  1936-1957   Yurka  Blanche   F  1887.0  1974.0
# 6844    George Zucco  1930-1951   Zucco   George   M  1886.0  1960.0
#
#                                type      orig
# 1                        R:straight  comedian
# ...

# %%
actors_data.drop(actors_data.iloc[:, 9:6844], inplace=True, axis=1)
display(actors_data)
# Out:
#                stage        dow   birth      giv gen     dob     dod  \
# 1         Bud Abbott  1939-1956  Abbott  William   M  1895.0  1974.0
# 7        Walter Abel  1935-1974    Abel   Walter   M  1898.0  1987.0
# 16    Rodolfo Acosta  1948-1967  Acosta  Rodolfo   M  1920.0  1974.0
# 17       Eddie Acuff  1935-1947   Acuff    Eddie   M  1902.0  1956.0
# 18        Jean Adair  1922-1947   Adair     Jean   F  1872.0  1956.0
# ...              ...        ...     ...      ...  ..     ...     ...
# 6809       Gig Young  1940-1978    Barr    Byron   M  1913.0  1978.0
# 6814    Robert Young  1931-1975   Young   Robert   M  1907.0  1998.0
# 6815    Roland Young  1922-1953   Young   Roland   M  1887.0  1953.0
# 6824   Blanche Yurka  1936-1957   Yurka  Blanche   F  1887.0  1974.0
# 6844    George Zucco  1930-1951   Zucco   George   M  1886.0  1960.0
#
#                                type      orig
# 1                        R:straight  comedian
# ...

# %%
actors_data.insert(9,'Age', Age )

# %%
actors_data
# Out:
#                stage        dow   birth      giv gen     dob     dod  \
# 1         Bud Abbott  1939-1956  Abbott  William   M  1895.0  1974.0
# 7        Walter Abel  1935-1974    Abel   Walter   M  1898.0  1987.0
# 16    Rodolfo Acosta  1948-1967  Acosta  Rodolfo   M  1920.0  1974.0
# 17       Eddie Acuff  1935-1947   Acuff    Eddie   M  1902.0  1956.0
# 18        Jean Adair  1922-1947   Adair     Jean   F  1872.0  1956.0
# ...              ...        ...     ...      ...  ..     ...     ...
# 6809       Gig Young  1940-1978    Barr    Byron   M  1913.0  1978.0
# 6814    Robert Young  1931-1975   Young   Robert   M  1907.0  1998.0
# 6815    Roland Young  1922-1953   Young   Roland   M  1887.0  1953.0
# 6824   Blanche Yurka  1936-1957   Yurka  Blanche   F  1887.0  1974.0
# 6844    George Zucco  1930-1951   Zucco   George   M  1886.0  1960.0
#
#                                type      orig   Age
# 1                        R:straight  comedian  79.0
# ...

# %%
actors_data['Age'] = actors_data['Age'].astype(int)

# %%
actors_data['Age'].unique()
# Out:
# array([   79,    89,    54,    84,    73,    83,    37,    55,    85,
#           81,    35,    71,    67,    57,    68,    76,    74,    72,
#           58,    80,    30,    88,    62,    69,    92,    94,    65,
#           78,    77,    39,    46,    51,    66,    63,    53,    86,
#           82,    90,    61,    91,    44,    59,    50,    49,    70,
#           60,    87,    33,    56,    41,    64,    43,    47,    75,
#           48,    52,   -28,   100,    95,    45,    99,    36,    42,
#           93,    34,    28,    40,    22,    24,    31,    26,    25,
#           38,    29,    32, -1829,    97, -1820, -1824,     3,    18,
#           98,     8,    23,   -21,   -15,    16,   101,     1,    20,
#          -25,   102])

# %%
b = actors_data['Age'].count()
print(b)
b1 = actors_data[(actors_data['Age']>15) &(actors_data['Age']<=25)]['Age'].count()
print(b1)
b3 = actors_data[(actors_data['Age']>40) &(actors_data['Age']<=60)]['Age'].count()
print(b3)
b4 = actors_data[(actors_data['Age']>60) &(actors_data['Age']<=80)]['Age'].count()
print(b4)
b2 = actors_data[(actors_data['Age']>25) &(actors_data['Age']<=40)]['Age'].count()
print(b2)
b5 = actors_data[(actors_data['Age']>80) &(actors_data['Age']<=100)]['Age'].count()
print(b5)
pb1 = ((b1/b)*100)
pb2 = ((b2/b)*100)
pb3 = ((b3/b)*100)
pb4 = ((b4/b)*100)
pb5 = ((b5/b)*100)
print(pb1,pb2,pb3,pb4,pb5)

y = np.array([pb1,pb2,pb3,pb4,pb5])

strpb1 = "Death between 15 and 25 " + str(pb1) + "%"
strpb2 = "Death between 25 and 40 " + str(pb2) + "%"
strpb3 = "Death between 40 and 60 " + str(pb3) + "%"
strpb4 = "Death between 60 and 80 " + str(pb4) + "%"
strpb5 = "Death between 80 and 100 " + str(pb5) + "%"

mylabel = [strpb1,strpb2, strpb3,strpb4,strpb5]
plt.pie(y,labels = mylabel)
plt.show()
# Out:
# 1925
# 9
# 469
# 962
# 88
# 384
# 0.4675324675324675 4.571428571428571 24.363636363636363 49.97402597402598 19.948051948051948

# %%
actors_data['dob'] = actors_data['dob'].astype(int)
avg = round(actors_data['dob'].mean())
print(avg)
# Out:
# 1201

# %%
actors_data.describe()
# Out:
#                dob
# count  6850.000000
# mean   1649.619124
# std     347.134315
# min    1201.000000
# 25%    1201.000000
# 50%    1898.000000
# 75%    1924.000000
# max    1994.000000

# %%
actors_data['dob'].var()
# Out:
# 120502.23263173377

# %%
actors_data.dropna()
# Out:
#                     stage        dow       birth           giv gen   dob  \
# 1              Bud Abbott  1939-1956      Abbott       William   M  1895
# 3           George Abbott  1928-1958      Abbott        George   M  1887
# 4             John Abbott  1937-1975      Abbott          John   M  1905
# 5           Philip Abbott  1957-1973      Abbott        Philip   M  1923
# 7             Walter Abel  1935-1974        Abel        Walter   M  1898
# ...                   ...        ...         ...           ...  ..   ...
# 6837       Mai Zetterling  1944-1983  Zetterling           Mai   F  1925
# 6839        Sonja Ziemann  1942-1970     Ziemann         Sonja   F  1926
# 6840  Efrem Zimbalist~Jr.  1949-1978   Zimbalist     Efrem Jr.   M  1918
# 6843          Vera Zorina  1939-1944     Hartwig  Eva Brigitta   F  1917
# 6844         George Zucco  1930-1951       Zucco        George   M  1886
#
#        dod                             type      orig
# ...

# %%
data_column_category = actors_data.select_dtypes(exclude=[np.number]).columns
# data_column_category
actors_data[data_column_category].head()
# Out:
#             stage        dow   birth      giv gen   dod  \
# 0    Willie Aames        NaN   Aames  William   M  199x
# 1      Bud Abbott  1939-1956  Abbott  William   M  1974
# 2  Diahnne Abbott  1976-1982     NaN      NaN   F  199x
# 3   George Abbott  1928-1958  Abbott   George   M  199x
# 4     John Abbott  1937-1975  Abbott     John   M  199x
#
#                               type      orig
# 0                              RU:       \Am
# 1                       R:straight  comedian
# 2                           R:sexy       \Am
# 3           R:playwright, producer       \Am
# 4  R:staring eyes, eccentric parts       \Br

# %%
from sklearn.preprocessing import LabelEncoder
label_encoder = LabelEncoder()

for i in data_column_category:
    actors_data[i] = label_encoder.fit_transform(actors_data[i])

actors_data.head()
# Out:
#    stage   dow  birth   giv  gen   dob  dod  type  orig
# 0   6730  2047      2  1939    1  1960   96  1902    26
# 1    777   944      3  1939    1  1895   59  1593   170
# 2   1419  1887   3363  2005    0  1201   96  1392    26
# 3   2181   474      3   670    1  1887   96  1213    26
# 4   3233   882      3   947    1  1905   96  1570    45

# %%
actors_data
# Out:
#       stage   dow  birth   giv  gen   dob  dod  type  orig
# 0      6730  2047      2  1939    1  1960   96  1902    26
# 1       777   944      3  1939    1  1895   59  1593   170
# 2      1419  1887   3363  2005    0  1201   96  1392    26
# 3      2181   474      3   670    1  1887   96  1213    26
# 4      3233   882      3   947    1  1905   96  1570    45
# ...     ...   ...    ...   ...  ...   ...  ...   ...   ...
# 6845   1338  2047   3363  2005    1  1201   96  1902   161
# 6846   3091  2047   3363  2005    1  1201   96  1902   161
# 6847   1259  2047   3363  2005    0  1201   96  1902   161
# 6848   2062  2047   3363  2005    1  1201   96  1902   161
# 6849   1265  2047   3363  2005    1  1201   96  1902   161
#
# [6850 rows x 9 columns]

# %%
actors_data.var()
# Out:
# stage    3.885655e+06
# dow      3.838585e+05
# birth    1.243615e+06
# giv      4.398050e+05
# gen      2.917577e-01
# dob      1.205022e+05
# dod      4.509862e+02
# type     3.953077e+05
# orig     3.645140e+03
# dtype: float64

# %%
from sklearn import preprocessing

scaler = preprocessing.MinMaxScaler()
names = actors_data.columns
d = scaler.fit_transform(actors_data)
scaled_df = pd.DataFrame(d, columns=names)
scaled_df.head()
# Out:
#       stage       dow     birth       giv  gen       dob       dod      type  \
# 0  0.990288  1.000000  0.000595  0.967082  0.5  0.957125  0.842105  0.994770
# 1  0.114332  0.461163  0.000892  0.967082  0.5  0.875158  0.517544  0.833159
# 2  0.208799  0.921837  1.000000  1.000000  0.0  0.000000  0.842105  0.728033
# 3  0.320924  0.231558  0.000892  0.334165  0.5  0.865069  0.842105  0.634414
# 4  0.475721  0.430874  0.000892  0.472319  0.5  0.887768  0.842105  0.821130
#
#        orig
# 0  0.148571
# 1  0.971429
# 2  0.148571
# 3  0.148571
# 4  0.257143

# %%
import scipy.stats as stats
scaled_df['dob_zscore'] = stats.zscore(scaled_df['dob'])
display(scaled_df)
# Out:
#          stage       dow     birth       giv  gen       dob       dod  \
# 0     0.990288  1.000000  0.000595  0.967082  0.5  0.957125  0.842105
# 1     0.114332  0.461163  0.000892  0.967082  0.5  0.875158  0.517544
# 2     0.208799  0.921837  1.000000  1.000000  0.0  0.000000  0.842105
# 3     0.320924  0.231558  0.000892  0.334165  0.5  0.865069  0.842105
# 4     0.475721  0.430874  0.000892  0.472319  0.5  0.887768  0.842105
# ...        ...       ...       ...       ...  ...       ...       ...
# 6845  0.196881  1.000000  1.000000  1.000000  0.5  0.000000  0.842105
# 6846  0.454826  1.000000  1.000000  1.000000  0.5  0.000000  0.842105
# 6847  0.185256  1.000000  1.000000  1.000000  0.0  0.000000  0.842105
# 6848  0.303414  1.000000  1.000000  1.000000  0.5  0.000000  0.842105
# 6849  0.186139  1.000000  1.000000  1.000000  0.5  0.000000  0.842105
#
#           type      orig  dob_zscore
# 0     0.994770  0.148571    0.894189
# 1     0.833159  0.971429    0.706927
# ...
